# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # High LEARNING RATE

# %%
path = 'C:/Users/Alex/Documents/CS525/project/results/high_lo_lr_breakout_Results/First_Results/Low_LR/'
col = 'episode_moving_average_30'


### TRAINING
dqn = pd.read_csv(path+'DQN/15000_training_metrics.csv')
ddqn = pd.read_csv(path+'DDQN/14000_training_metrics.csv')
ddqn_ms = pd.read_csv(path+'DDQN_MS/16000_training_metrics.csv')
duel = pd.read_csv(path+'DuelingDQN/15000_training_metrics.csv')

plt.plot(dqn['episode'], dqn[col], label = 'DQN')
plt.plot(ddqn['episode'], ddqn[col], label = 'Double DQN')
plt.plot(ddqn_ms['episode'], ddqn_ms[col], label = 'Double DQN Multi-step')
plt.plot(duel['episode'], duel[col], label = 'Dueling DQN')
plt.legend(loc = 'best')
plt.title('DQN Family: 1.5e-4 Learning Rate Training')
plt.xlabel('Training Episodes')
plt.ylabel('Breakout 30-Episode Moving Average Reward')
plt.show()

# %%
path = 'C:/Users/Alex/Documents/CS525/project/results/high_lo_lr_breakout_Results/First_Results/Low_LR/'
col = 'test_reward_average_last_100'
# TESTING
dqn = pd.read_csv(path+'DQN/15000_test_metrics.csv')
#print(dqn)
ddqn = pd.read_csv(path+'DDQN/14000_test_metrics.csv')
ddqn_ms = pd.read_csv(path+'DDQN_MS/16000_test_metrics.csv')
duel = pd.read_csv(path+'DuelingDQN/15000_test_metrics.csv')


plt.plot(dqn['episode'], dqn[col], label = 'DQN')
plt.plot(ddqn['episode'], ddqn[col], label = 'Double DQN')
plt.plot(ddqn_ms['episode'], ddqn_ms[col], label = 'Double DQN Multi-step')
plt.plot(duel['episode'], duel[col], label = 'Dueling DQN')
plt.legend(loc = 'best')
plt.title('DQN Family: 1e-4 Learning Rate Testing')
plt.xlabel('Training Episodes')
plt.ylabel('Breakout 100-Test Average Reward')
plt.show()

# %% [markdown]
# # .00015 LEARNING RATE

# %%
path = 'C:/Users/Alex/Documents/CS525/project/results/high_lo_lr_breakout_Results/First_Results/High_LR/'
col = 'episode_moving_average_30'
# TRAINING
dqn = pd.read_csv(path+'DQN/14000_training_metrics.csv')
ddqn = pd.read_csv(path+'DDQN/20000_training_metrics.csv')
ddqn_ms = pd.read_csv(path+'DDQN_MS/15000_training_metrics.csv')

plt.plot(dqn['episode'], dqn[col], label = 'DQN')
plt.plot(ddqn['episode'], ddqn[col], label = 'Double DQN')
plt.plot(ddqn_ms['episode'], ddqn_ms[col], label = 'Double DQN Multi-step')
plt.legend(loc = 'best')
plt.title('DQN Family: 1.5e-4 Learning Rate Training')
plt.xlabel('Training Episodes')
plt.ylabel('Breakout 30-Episode Moving Average Reward')
plt.show()

# %%
path = 'C:/Users/Alex/Documents/CS525/project/results/high_lo_lr_breakout_Results/First_Results/High_LR/'
col = 'test_reward_average_last_100'
# TESTING
dqn = pd.read_csv(path+'DQN/14000_test_metrics.csv')
ddqn = pd.read_csv(path+'DDQN/20000_test_metrics.csv')
ddqn_ms = pd.read_csv(path+'DDQN_MS/15000_test_metrics.csv')

plt.plot(dqn['episode'], dqn[col], label = 'DQN')
plt.plot(ddqn['episode'], ddqn[col], label = 'Double DQN')
plt.plot(ddqn_ms['episode'], ddqn_ms[col], label = 'Double DQN Multi-step')
plt.legend(loc = 'best')
plt.title('DQN Family: 1.5e-4 Learning Rate Testing')
plt.xlabel('Training Episodes')
plt.ylabel('Breakout 100-Test Average Reward')
plt.show()
